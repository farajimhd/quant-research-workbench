# %% [markdown]
# # News Reaction Model V9 Diagram
#
# Renders the unchanged V8 encoder and the four-class opportunity heads.

# %%
from pathlib import Path
import torch
from research.mlops.model_artifacts import parameter_summary, write_model_artifacts
from research.news_reaction_model.v9.config import LoaderConfig, ModelConfig
from research.news_reaction_model.v9.data import make_dummy_batch
from research.news_reaction_model.v9.model import NewsReactionModelV9, build_model_mermaid
from research.news_reaction_model.v9.opportunity import opportunity_contract
loader_config, model_config = LoaderConfig(), ModelConfig()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = NewsReactionModelV9(model_config).to(device)
print(parameter_summary(model))
write_model_artifacts(model=model, artifact_dir=Path('artifacts/news_reaction_model_v9'), model_config=model_config, input_contract={'openai_embedding': ['B', loader_config.openai_embedding_dim], 'stock_state': ['B', loader_config.stock_state_dim], 'channel_mask': ['B', 2]}, output_contract={'opportunity_logits': opportunity_contract()}, architecture_mermaid=build_model_mermaid(), summary_notes='V9 changes only the V8 supervised task to four-class opportunity prediction.', dummy_input_factory=lambda: ((make_dummy_batch(2, loader_config, device=device).x,), {}))
