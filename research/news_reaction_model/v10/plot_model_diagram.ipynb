# %% [markdown]
# # News Reaction Model V10 Diagram
#
# Renders the unchanged V9 encoder and the three-class opportunity heads.

# %%
from pathlib import Path
import torch
from research.mlops.model_artifacts import parameter_summary, write_model_artifacts
from research.news_reaction_model.v10.config import LoaderConfig, ModelConfig
from research.news_reaction_model.v10.data import make_dummy_batch
from research.news_reaction_model.v10.model import NewsReactionModelV10, build_model_mermaid
from research.news_reaction_model.v10.opportunity import opportunity_contract
loader_config, model_config = LoaderConfig(), ModelConfig()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = NewsReactionModelV10(model_config).to(device)
print(parameter_summary(model))
write_model_artifacts(model=model, artifact_dir=Path('artifacts/news_reaction_model_v10'), model_config=model_config, input_contract={'openai_embedding': ['B', loader_config.openai_embedding_dim], 'stock_state': ['B', loader_config.stock_state_dim], 'channel_mask': ['B', 2]}, output_contract={'opportunity_logits': opportunity_contract()}, architecture_mermaid=build_model_mermaid(), summary_notes='V10 changes only V9 opportunity prediction from four classes to three.', dummy_input_factory=lambda: ((make_dummy_batch(2, loader_config, device=device).x,), {}))
