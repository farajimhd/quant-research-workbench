# %% [markdown]
# # News Reaction Model V6 Diagram
#
# Creates V6 with frozen V5 lexical inputs plus its financial-numeric channel and writes architecture artifacts.

# %%
from pathlib import Path
import torch
from research.mlops.model_artifacts import parameter_summary, write_model_artifacts
from research.news_reaction_model.v6.config import LoaderConfig, ModelConfig
from research.news_reaction_model.v6.data import make_dummy_batch
from research.news_reaction_model.v6.model import NewsReactionModelV6, build_model_mermaid
from research.news_reaction_model.v6.ranges import describe_ranges
loader_config, model_config = LoaderConfig(), ModelConfig()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = NewsReactionModelV6(model_config).to(device)
print(parameter_summary(model))
write_model_artifacts(model=model, artifact_dir=Path('artifacts/news_reaction_model_v6'), model_config=model_config, input_contract={'word_indices': ['NNZ_word'], 'word_offsets': ['B+1'], 'word_weights': ['NNZ_word'], 'char_indices': ['NNZ_char'], 'char_offsets': ['B+1'], 'char_weights': ['NNZ_char'], 'numeric_indices': ['NNZ_numeric'], 'numeric_offsets': ['B+1'], 'numeric_weights': ['NNZ_numeric'], 'numeric_dense': ['B', 24], 'channel_mask': ['B', 3]}, output_contract={'range_logits': describe_ranges()}, architecture_mermaid=build_model_mermaid(), summary_notes='V6 frozen V5 lexical adapters plus financial-number channel; prediction heads unchanged.', dummy_input_factory=lambda: ((make_dummy_batch(2, loader_config, device=device).x,), {}))
