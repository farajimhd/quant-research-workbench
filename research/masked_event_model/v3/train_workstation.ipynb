# %% [markdown]
# # Masked Event Model v3 Workstation Training
#
# Run this notebook from the runtime folder on the workstation. It verifies paths and prints terminal commands; it does not run long training inside the notebook.

# %%
from pathlib import Path
ROOT = Path.cwd()
CACHE_ROOT = Path(r'D:/market-data/flatfiles/us_stocks_sip/derived/event_chunks_v2')
CANONICAL_ROOT = Path(r'D:/market-data/flatfiles/us_stocks_sip/derived/canonical_events_v2')
TRAIN = ROOT / 'run_train.ps1'
print('root', ROOT)
print('cache exists', CACHE_ROOT.exists(), CACHE_ROOT)
print('canonical exists', CANONICAL_ROOT.exists(), CANONICAL_ROOT)
print('run script exists', TRAIN.exists(), TRAIN)

# %%
print('Run in PowerShell:')
print(f'cd {ROOT}')
print(r'.\run_train.ps1')
